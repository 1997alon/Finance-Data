# %%
import pandas as pd
dt = pd.read_pickle('final_task_bad_data.pickle')

# %%
copy = dt.copy()
copy.reset_index(inplace=True)

# %%
# bad_close will contain all the "bad" rows
bad_close = copy[(copy["High"] < copy["Close"]) | (copy["Low"] > copy["Close"])]
bad_close
# Out:
#                          Date        Open        High         Low   Close  \
# 150 2022-09-23 00:00:00-04:00  100.293137  100.851316   97.701578  9999.0
# 151 2022-09-26 00:00:00-04:00   98.628560  100.333012   97.741452     0.0
# 152 2022-09-27 00:00:00-04:00   99.206673   99.316317   95.119994  9999.0
# 300 2023-05-01 00:00:00-04:00  102.077323  102.276670  101.279918   -20.0
#
#          Volume
# 150  11976900.0
# 151   9760500.0
# 152  13360200.0
# 300   6909500.0

# %%
copy.loc[150:152, "Close"] = None
copy.loc[300, "Close"] = None
# recheck if there are more "bad" rows
bad_close = copy[(copy["High"] < copy["Close"]) | (copy["Low"] > copy["Close"])]
bad_close
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume]
# Index: []

# %%
# bad_open will contain all the "bad" rows
bad_open = copy[(copy["High"] < copy["Open"]) | (copy["Low"] > copy["Open"])]
bad_open
# Out:
#                          Date       Open        High         Low       Close  \
# 250 2023-02-16 00:00:00-05:00  97.200627  107.669094  105.356631  105.486214
# 296 2023-04-25 00:00:00-04:00  89.057157   99.386087   97.691612   97.691612
#
#         Volume
# 250  9479900.0
# 296  6511400.0

# %%
copy.loc[250, "Open"] = None
copy.loc[296, "Open"] = None
# recheck if there are more "bad" rows
bad_open = copy[(copy["High"] < copy["Open"]) | (copy["Low"] > copy["Open"])]
bad_open
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume]
# Index: []

# %%
# check that all the "bad" rows have NaN value 
copy[copy.isna().any(axis=1)]
# Out:
#                          Date        Open        High         Low       Close  \
# 10  2022-03-04 00:00:00-05:00  143.542169  143.791357  139.096666  140.262863
# 150 2022-09-23 00:00:00-04:00  100.293137  100.851316   97.701578         NaN
# 151 2022-09-26 00:00:00-04:00   98.628560  100.333012   97.741452         NaN
# 152 2022-09-27 00:00:00-04:00   99.206673   99.316317   95.119994         NaN
# 250 2023-02-16 00:00:00-05:00         NaN  107.669094  105.356631  105.486214
# 296 2023-04-25 00:00:00-04:00         NaN   99.386087   97.691612   97.691612
# 300 2023-05-01 00:00:00-04:00  102.077323  102.276670  101.279918         NaN
#
#          Volume
# 10          NaN
# 150  11976900.0
# 151   9760500.0
# 152  13360200.0
# 250   9479900.0
# 296   6511400.0
# 300   6909500.0

# %%
def mean_imputation_without_leakage(srs, high, low):
    filled_srs = srs.copy()
    for index in range(len(srs)):
        if pd.isnull(srs.iloc[index]):
            valid_values = srs.where((srs >= low[index]) & (srs <= high[index])).dropna() 
            filled_srs.iloc[index] = valid_values.expanding().mean().iloc[-1] 
    return filled_srs

# %%
# fix open and close
copy["Close"] = mean_imputation_without_leakage(copy['Close'], copy['High'], copy['Low'])
copy["Open"] = mean_imputation_without_leakage(copy['Open'], copy['High'], copy['Low'])

# %%
# recheck if there are still more "bad" rows
bad_close = copy[(copy["High"] < copy["Close"]) | (copy["Low"] > copy["Close"])]
bad_close
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume]
# Index: []

# %%
# recheck if there are still more "bad" rows
bad_open = copy[(copy["High"] < copy["Open"]) | (copy["Low"] > copy["Open"])]
bad_open
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume]
# Index: []

# %%
def mean_imputation_without_leakage(srs):
    return srs.fillna(srs.expanding().mean())

# fix Volume
copy["Volume"] = mean_imputation_without_leakage(copy['Volume'])

# %%
# check if there are still NaN values
copy[copy.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume]
# Index: []

# %%
copy.to_pickle('fixed_data.pickle')

# %%
import wrds

conn=wrds.Connection()
tables = conn.list_tables(library='crsp')
# Out:
# Loading library list...
# Done

# %%
def get_stock_data(symbol: str, start_date: str, end_date: str) -> pd.DataFrame:
    """
    Fetches stock data for a given symbol within a specified date range
    from WRDS CRSP database.

    Args:
        symbol (str): Ticker symbol of the stock.
        start_date (str): Start date in 'YYYY-MM-DD' format.
        end_date (str): End date in 'YYYY-MM-DD' format.
        conn (wrds.Connection): Connection object to WRDS database.

    Returns:
        pd.DataFrame: DataFrame containing the fetched stock data.
    """
    query = f"""SELECT c.date AS Date,
                        c.permco AS company_code,
                        c.permno AS security_code,
                        c.openprc AS Open, 
                        c.askhi AS High,
                        c.bidlo AS Low, 
                        c.prc AS Close, 
                        c.vol AS Volume,
                        c.cfacpr AS splits_adjustment_factor,
                        c.ret AS adjusted_returns,
                        c.retx AS returns_without_dividends,
                        i.ticker AS symbol,
                        i.uesindustry AS industry,
                        d.divamt AS dividend_amount
                    FROM crsp.dsf c
                        JOIN crsp.stksecurityinfohdr i ON c.permno = i.permno
                        LEFT JOIN crsp.dse d ON c.permno = d.permno AND c.date = d.date
                    WHERE c.date >= '{start_date}'
                        AND c.date <= '{end_date}'
                        AND i.ticker = '{symbol}'
                """
    # conn = wrds.Connection()
    return conn.raw_sql(query, date_cols=['Date'])


df = get_stock_data(symbol='ANF', start_date='2018-01-01', end_date='2020-04-01')
df
# Out:
#            date  company_code  security_code   open    high      low  close  \
# 0    2018-01-02         22200          83976  17.64  18.300  17.5100  18.20
# 1    2018-01-03         22200          83976  18.30  18.590  18.1300  18.53
# 2    2018-01-04         22200          83976  18.41  18.550  17.0400  18.20
# 3    2018-01-05         22200          83976  18.20  18.540  17.9900  18.28
# 4    2018-01-08         22200          83976  18.41  18.555  17.9507  18.31
# ..          ...           ...            ...    ...     ...      ...    ...
# 561  2020-03-26         22200          83976   9.71  10.620   9.1000  10.00
# 562  2020-03-27         22200          83976   9.40  10.100   9.0000   9.91
# 563  2020-03-30         22200          83976   9.80   9.800   9.1400   9.31
# 564  2020-03-31         22200          83976   9.31   9.585   8.7600   9.09
# 565  2020-04-01         22200          83976   8.47   8.490   8.0300   8.17
#
#         volume  splits_adjustment_factor  adjusted_returns  \
# 0    2275956.0                       1.0          0.044177
# 1    2112677.0                       1.0          0.018132
# 2    3580819.0                       1.0         -0.017809
# 3    2288929.0                       1.0          0.004396
# 4    2417879.0                       1.0          0.001641
# ..         ...                       ...               ...
# 561  5052422.0                       1.0          0.055966
# 562  3034780.0                       1.0         -0.009000
# 563  1588860.0                       1.0         -0.060545
# 564  2346424.0                       1.0         -0.023631
# 565  2383085.0                       1.0         -0.101210
#
#      returns_without_dividends symbol industry  dividend_amount
# 0                     0.044177    ANF   CONDIS              NaN
# 1                     0.018132    ANF   CONDIS              NaN
# 2                    -0.017809    ANF   CONDIS              NaN
# 3                     0.004396    ANF   CONDIS              NaN
# 4                     0.001641    ANF   CONDIS              NaN
# ..                         ...    ...      ...              ...
# 561                   0.055966    ANF   CONDIS              NaN
# 562                  -0.009000    ANF   CONDIS              NaN
# 563                  -0.060545    ANF   CONDIS              NaN
# 564                  -0.023631    ANF   CONDIS              NaN
# 565                  -0.101210    ANF   CONDIS              NaN
#
# [566 rows x 14 columns]

# %%
df["dividend_amount"] = df["dividend_amount"].fillna(0)
df["dir"] = (1 - (df["dividend_amount"] / df["close"].shift(1)))
df.insert(0, 'index', df.index)
df
# Out:
#      index        date  company_code  security_code   open    high      low  \
# 0        0  2018-01-02         22200          83976  17.64  18.300  17.5100
# 1        1  2018-01-03         22200          83976  18.30  18.590  18.1300
# 2        2  2018-01-04         22200          83976  18.41  18.550  17.0400
# 3        3  2018-01-05         22200          83976  18.20  18.540  17.9900
# 4        4  2018-01-08         22200          83976  18.41  18.555  17.9507
# ..     ...         ...           ...            ...    ...     ...      ...
# 561    561  2020-03-26         22200          83976   9.71  10.620   9.1000
# 562    562  2020-03-27         22200          83976   9.40  10.100   9.0000
# 563    563  2020-03-30         22200          83976   9.80   9.800   9.1400
# 564    564  2020-03-31         22200          83976   9.31   9.585   8.7600
# 565    565  2020-04-01         22200          83976   8.47   8.490   8.0300
#
#      close     volume  splits_adjustment_factor  adjusted_returns  \
# 0    18.20  2275956.0                       1.0          0.044177
# 1    18.53  2112677.0                       1.0          0.018132
# 2    18.20  3580819.0                       1.0         -0.017809
# 3    18.28  2288929.0                       1.0          0.004396
# 4    18.31  2417879.0                       1.0          0.001641
# ..     ...        ...                       ...               ...
# 561  10.00  5052422.0                       1.0          0.055966
# 562   9.91  3034780.0                       1.0         -0.009000
# 563   9.31  1588860.0                       1.0         -0.060545
# 564   9.09  2346424.0                       1.0         -0.023631
# 565   8.17  2383085.0                       1.0         -0.101210
#
#      returns_without_dividends symbol industry  dividend_amount  dir
# 0                     0.044177    ANF   CONDIS              0.0  NaN
# 1                     0.018132    ANF   CONDIS              0.0  1.0
# 2                    -0.017809    ANF   CONDIS              0.0  1.0
# 3                     0.004396    ANF   CONDIS              0.0  1.0
# 4                     0.001641    ANF   CONDIS              0.0  1.0
# ..                         ...    ...      ...              ...  ...
# 561                   0.055966    ANF   CONDIS              0.0  1.0
# 562                  -0.009000    ANF   CONDIS              0.0  1.0
# 563                  -0.060545    ANF   CONDIS              0.0  1.0
# 564                  -0.023631    ANF   CONDIS              0.0  1.0
# 565                  -0.101210    ANF   CONDIS              0.0  1.0
#
# [566 rows x 16 columns]

# %%
df['cdir'] = df['dir'].shift(-1)[::-1].cumprod()[::-1]
df['cdir'] = df['cdir'].fillna(1.0)
df
# Out:
#      index        date  company_code  security_code   open    high      low  \
# 0        0  2018-01-02         22200          83976  17.64  18.300  17.5100
# 1        1  2018-01-03         22200          83976  18.30  18.590  18.1300
# 2        2  2018-01-04         22200          83976  18.41  18.550  17.0400
# 3        3  2018-01-05         22200          83976  18.20  18.540  17.9900
# 4        4  2018-01-08         22200          83976  18.41  18.555  17.9507
# ..     ...         ...           ...            ...    ...     ...      ...
# 561    561  2020-03-26         22200          83976   9.71  10.620   9.1000
# 562    562  2020-03-27         22200          83976   9.40  10.100   9.0000
# 563    563  2020-03-30         22200          83976   9.80   9.800   9.1400
# 564    564  2020-03-31         22200          83976   9.31   9.585   8.7600
# 565    565  2020-04-01         22200          83976   8.47   8.490   8.0300
#
#      close     volume  splits_adjustment_factor  adjusted_returns  \
# 0    18.20  2275956.0                       1.0          0.044177
# 1    18.53  2112677.0                       1.0          0.018132
# 2    18.20  3580819.0                       1.0         -0.017809
# 3    18.28  2288929.0                       1.0          0.004396
# 4    18.31  2417879.0                       1.0          0.001641
# ..     ...        ...                       ...               ...
# 561  10.00  5052422.0                       1.0          0.055966
# 562   9.91  3034780.0                       1.0         -0.009000
# 563   9.31  1588860.0                       1.0         -0.060545
# 564   9.09  2346424.0                       1.0         -0.023631
# 565   8.17  2383085.0                       1.0         -0.101210
#
#      returns_without_dividends symbol industry  dividend_amount  dir      cdir
# 0                     0.044177    ANF   CONDIS              0.0  NaN  0.908386
# 1                     0.018132    ANF   CONDIS              0.0  1.0  0.908386
# 2                    -0.017809    ANF   CONDIS              0.0  1.0  0.908386
# 3                     0.004396    ANF   CONDIS              0.0  1.0  0.908386
# 4                     0.001641    ANF   CONDIS              0.0  1.0  0.908386
# ..                         ...    ...      ...              ...  ...       ...
# 561                   0.055966    ANF   CONDIS              0.0  1.0  1.000000
# 562                  -0.009000    ANF   CONDIS              0.0  1.0  1.000000
# 563                  -0.060545    ANF   CONDIS              0.0  1.0  1.000000
# 564                  -0.023631    ANF   CONDIS              0.0  1.0  1.000000
# 565                  -0.101210    ANF   CONDIS              0.0  1.0  1.000000
#
# [566 rows x 17 columns]

# %%
df["adjusted_close"] = df["close"] * df["cdir"] / df["splits_adjustment_factor"]
df
# Out:
#      index        date  company_code  security_code   open    high      low  \
# 0        0  2018-01-02         22200          83976  17.64  18.300  17.5100
# 1        1  2018-01-03         22200          83976  18.30  18.590  18.1300
# 2        2  2018-01-04         22200          83976  18.41  18.550  17.0400
# 3        3  2018-01-05         22200          83976  18.20  18.540  17.9900
# 4        4  2018-01-08         22200          83976  18.41  18.555  17.9507
# ..     ...         ...           ...            ...    ...     ...      ...
# 561    561  2020-03-26         22200          83976   9.71  10.620   9.1000
# 562    562  2020-03-27         22200          83976   9.40  10.100   9.0000
# 563    563  2020-03-30         22200          83976   9.80   9.800   9.1400
# 564    564  2020-03-31         22200          83976   9.31   9.585   8.7600
# 565    565  2020-04-01         22200          83976   8.47   8.490   8.0300
#
#      close     volume  splits_adjustment_factor  adjusted_returns  \
# 0    18.20  2275956.0                       1.0          0.044177
# 1    18.53  2112677.0                       1.0          0.018132
# 2    18.20  3580819.0                       1.0         -0.017809
# 3    18.28  2288929.0                       1.0          0.004396
# 4    18.31  2417879.0                       1.0          0.001641
# ..     ...        ...                       ...               ...
# 561  10.00  5052422.0                       1.0          0.055966
# 562   9.91  3034780.0                       1.0         -0.009000
# 563   9.31  1588860.0                       1.0         -0.060545
# 564   9.09  2346424.0                       1.0         -0.023631
# 565   8.17  2383085.0                       1.0         -0.101210
#
#      returns_without_dividends symbol industry  dividend_amount  dir  \
# 0                     0.044177    ANF   CONDIS              0.0  NaN
# 1                     0.018132    ANF   CONDIS              0.0  1.0
# 2                    -0.017809    ANF   CONDIS              0.0  1.0
# 3                     0.004396    ANF   CONDIS              0.0  1.0
# 4                     0.001641    ANF   CONDIS              0.0  1.0
# ..                         ...    ...      ...              ...  ...
# 561                   0.055966    ANF   CONDIS              0.0  1.0
# 562                  -0.009000    ANF   CONDIS              0.0  1.0
# 563                  -0.060545    ANF   CONDIS              0.0  1.0
# 564                  -0.023631    ANF   CONDIS              0.0  1.0
# 565                  -0.101210    ANF   CONDIS              0.0  1.0
#
#          cdir  adjusted_close
# 0    0.908386       16.532627
# 1    0.908386       16.832394
# 2    0.908386       16.532627
# 3    0.908386       16.605298
# 4    0.908386       16.632549
# ..        ...             ...
# 561  1.000000       10.000000
# 562  1.000000        9.910000
# 563  1.000000        9.310000
# 564  1.000000        9.090000
# 565  1.000000        8.170000
#
# [566 rows x 18 columns]

# %%
df["ratio"] = df["adjusted_close"] / df["close"]
df["adjusted_open"] = df["open"] * df["ratio"]
df["adjusted_high"] = df["high"] * df["ratio"]
df["adjusted_low"] = df["low"] * df["ratio"]
df
# Out:
#      index        date  company_code  security_code   open    high      low  \
# 0        0  2018-01-02         22200          83976  17.64  18.300  17.5100
# 1        1  2018-01-03         22200          83976  18.30  18.590  18.1300
# 2        2  2018-01-04         22200          83976  18.41  18.550  17.0400
# 3        3  2018-01-05         22200          83976  18.20  18.540  17.9900
# 4        4  2018-01-08         22200          83976  18.41  18.555  17.9507
# ..     ...         ...           ...            ...    ...     ...      ...
# 561    561  2020-03-26         22200          83976   9.71  10.620   9.1000
# 562    562  2020-03-27         22200          83976   9.40  10.100   9.0000
# 563    563  2020-03-30         22200          83976   9.80   9.800   9.1400
# 564    564  2020-03-31         22200          83976   9.31   9.585   8.7600
# 565    565  2020-04-01         22200          83976   8.47   8.490   8.0300
#
#      close     volume  splits_adjustment_factor  ...  symbol  industry  \
# 0    18.20  2275956.0                       1.0  ...     ANF    CONDIS
# 1    18.53  2112677.0                       1.0  ...     ANF    CONDIS
# 2    18.20  3580819.0                       1.0  ...     ANF    CONDIS
# 3    18.28  2288929.0                       1.0  ...     ANF    CONDIS
# 4    18.31  2417879.0                       1.0  ...     ANF    CONDIS
# ..     ...        ...                       ...  ...     ...       ...
# 561  10.00  5052422.0                       1.0  ...     ANF    CONDIS
# 562   9.91  3034780.0                       1.0  ...     ANF    CONDIS
# 563   9.31  1588860.0                       1.0  ...     ANF    CONDIS
# 564   9.09  2346424.0                       1.0  ...     ANF    CONDIS
# 565   8.17  2383085.0                       1.0  ...     ANF    CONDIS
#
#     dividend_amount  dir      cdir  adjusted_close     ratio  adjusted_open  \
# 0               0.0  NaN  0.908386       16.532627  0.908386      16.023931
# 1               0.0  1.0  0.908386       16.832394  0.908386      16.623465
# 2               0.0  1.0  0.908386       16.532627  0.908386      16.723388
# 3               0.0  1.0  0.908386       16.605298  0.908386      16.532627
# 4               0.0  1.0  0.908386       16.632549  0.908386      16.723388
# ..              ...  ...       ...             ...       ...            ...
# 561             0.0  1.0  1.000000       10.000000  1.000000       9.710000
# 562             0.0  1.0  1.000000        9.910000  1.000000       9.400000
# 563             0.0  1.0  1.000000        9.310000  1.000000       9.800000
# 564             0.0  1.0  1.000000        9.090000  1.000000       9.310000
# 565             0.0  1.0  1.000000        8.170000  1.000000       8.470000
#
#      adjusted_high  adjusted_low
# 0        16.623465     15.905840
# 1        16.886897     16.469040
# 2        16.850562     15.478899
# 3        16.841478     16.341866
# 4        16.855104     16.306166
# ..             ...           ...
# 561      10.620000      9.100000
# 562      10.100000      9.000000
# 563       9.800000      9.140000
# 564       9.585000      8.760000
# 565       8.490000      8.030000
#
# [566 rows x 22 columns]
